# %%
# !python run_retrieval.py
# Out:
# Added /home/asasin/NLP_Project/DEXTER to sys.path
# CUDA available: True
# Using GPU: NVIDIA A100 80GB PCIe
# ✓ Successfully imported DEXTER modules
# ...
# CONTRIEVER RETRIEVAL - Top-K Document Retrieval
# ...
# ✓ Output directory: output
# ✓ Embeddings directory: indices/corpus
# Converting corpus to Evidence objects...
# ✓ Created 526329 Evidence objects
# Converting queries to Question objects...
# ✓ Created 1200 Question objects
#
# ...
# Initializing Contriever Retriever...
# ...
#
# Loading Contriever from local: models/contriever
#
# ...
# Starting Retrieval Process...
# ...
# Retrieving top-5 documents for 1200 queries...
#
# Computing corpus embeddings (first time)...
# Batches: 100%|██████████████████████████████| 2056/2056 [12:20<00:00,  2.78it/s]
# Saving corpus embeddings to indices/corpus/embeddings.pt...
# ✓ Embeddings saved
#
# Encoding queries...
# Batches: 100%|████████████████████████████████████| 5/5 [00:00<00:00, 15.66it/s]
# ✓ Retrieval completed successfully
#
# ...
# Processing and Saving Results...
# ...

# %%
# !python evaluate_retrieval.py
# Out:
# ...
# RETRIEVAL EVALUATION - Answer Generation
# ...
# Device: cuda
#
# Loading Flan-T5 locally: models/flan-t5-base
# ✓ Model loaded
# ✓ Loaded 1200 dev questions
#
# ...
# EVALUATING TOP-1 RETRIEVAL
# ...
# ✓ Loaded retrieval results: 1200 queries
# Top-1: 100%|████████████████████████████████| 1200/1200 [00:58<00:00, 20.50it/s]
# ✓ EM: 0.2100 | F1: 0.2607
# ✓ Saved to results_new/top_1_answers.json
#
# ...
# EVALUATING TOP-3 RETRIEVAL
# ...
# ✓ Loaded retrieval results: 1200 queries
# Top-3: 100%|████████████████████████████████| 1200/1200 [00:58<00:00, 20.63it/s]
# ✓ EM: 0.2158 | F1: 0.2636
# ✓ Saved to results_new/top_3_answers.json
#
# ...
# EVALUATING TOP-5 RETRIEVAL
# ...
# ✓ Loaded retrieval results: 1200 queries
# Top-5: 100%|████████████████████████████████| 1200/1200 [01:02<00:00, 19.29it/s]
# ✓ EM: 0.2175 | F1: 0.2700
# ✓ Saved to results_new/top_5_answers.json
#
# ...
# SUMMARY
# ...
# top_1: EM=0.2100, F1=0.2607
# top_3: EM=0.2158, F1=0.2636
# top_5: EM=0.2175, F1=0.2700
# ...

# %%
# !python run_oracle_evaluation.py
# Out:
# ...
# ORACLE EVALUATION - Upper Bound with Ground Truth Documents
# ...
# Device: cuda
#
# Loading Flan-T5 from: models/flan-t5-base
# ✓ Flan-T5 loaded
# ✓ Loaded 1200 dev questions
# ✓ Loaded corpus: 526329 documents
# Creating title index...
# ✓ Indexed 494940 titles
#
# ...
# PROCESSING ORACLE PREDICTIONS
# ...
# Oracle Evaluation: 100%|████████████████████| 1200/1200 [01:11<00:00, 16.86it/s]
#
# ...
# ORACLE EVALUATION RESULTS
# ...
# Total queries: 1200
# Exact Match: 0.3492 (419/1200)
# F1 Score: 0.4428
# Average oracle docs per query: 2.44
# Queries with no oracle docs: 0
# Queries with missing docs in corpus: 0
#
# ✓ Saved answers to: results/oracle_answers.json
# ✓ Saved metrics to: results/oracle_metrics.json
# ...

# %%
# !python run_random_negatives.py
# Out:
# ...
# STEP 3: RANDOM NEGATIVE SAMPLING
# ...
# Device: cuda
#
# Loading Flan-T5 locally: models/flan-t5-base
# Loaded dev: 1200
# Loaded corpus docs: 526329
#
# ...
# CONFIG: 1plus1random (top-1 + 1 random)
# ...
# 1plus1random: 100%|█████████████████████████| 1200/1200 [01:43<00:00, 11.58it/s]
# EM: 0.2042 | F1: 0.2461
#
# ...
# CONFIG: 3plus3random (top-3 + 3 random)
# ...
# 3plus3random: 100%|█████████████████████████| 1200/1200 [02:00<00:00,  9.96it/s]
# EM: 0.2117 | F1: 0.2558
#
# ...
# CONFIG: 5plus5random (top-5 + 5 random)
# ...
# 5plus5random: 100%|█████████████████████████| 1200/1200 [02:24<00:00,  8.29it/s]
# EM: 0.1750 | F1: 0.2055
#
# ✓ Finished Step 3 (Random Negatives)

# %%
# !python run_retrieval_top10.py
# Out:
# Added /home/asasin/NLP_Project/DEXTER to sys.path
# CUDA available: True
# Using GPU: NVIDIA A100 80GB PCIe
# ✓ Successfully imported DEXTER modules
# ...
# CONTRIEVER RETRIEVAL - Top-10 Document Retrieval
# ...
# ✓ Output directory: output
# ✓ Embeddings directory: indices/corpus
# Converting corpus to Evidence objects...
# ✓ Created 526329 Evidence objects
# Converting queries to Question objects...
# ✓ Created 1200 Question objects
#
# ...
# Initializing Contriever...
# ...
#
# Loading Contriever from local: models/contriever
#
# ...
# Starting Retrieval Process...
# ...
# Retrieving top-10 documents for 1200 queries...
#
# Loading existing corpus embeddings from indices/corpus/embeddings.pt...
# ✓ Loaded 526329 corpus embeddings
#
# Encoding queries...
# Batches: 100%|██████████████████████████████████| 10/10 [00:01<00:00,  6.12it/s]
#
# Computing similarity scores...
# Building results...
# ✓ Retrieval completed successfully
#
# ...
# Processing and Saving Results...
# ...
# Creating corpus lookup dictionary...
# ...

# %%
# !python run_hard_negatives.py
# Out:
# ...
# STEP 4: HARD NEGATIVE SAMPLING (off-the-shelf retriever ranking)
# ...
# Device: cuda
# ✓ Loaded 1200 dev questions from data/dev.json
#
# Loading Flan-T5 locally...
# Path: models/flan-t5-base
# ✓ Flan-T5 loaded
#
# ...
# CONFIG: 1plus1hard  (top-1 + 1 hard)
# Retrieval file: output/top_10_retrieval_results.json
# ...
# 1plus1hard:   0%|                                      | 0/1200 [00:00<?, ?it/s]
# 🔍 SAMPLE DEBUG (Query: 8813f87c0bdd11eba7f7acde48001122):
#   Question: Who is the mother of the director of film Polish-Russian War (Film)?...
#   Gold answer: Małgorzata Braunek
#   Supporting titles (GT): {'Xawery Żuławski', 'Polish-Russian War (film)'}
#   Retrieved 10 docs total
#   Using first 1 retrieved (baseline): 1/1 are correct
#   Adding 1 hard negatives from remaining docs
#   Total contexts: 1 baseline + 1 hard
#   Top-5 retrieved titles: ['Polish-Russian War (film)', 'Mother (1999 film, Russia)', 'War is Over. Please Forget...', 'Sitora Alieva', 'Questions!/Answers?']
# ...

# %%
# !python adore_script.py
# Out:
# Importing libraries...
# Paths / config.........
# ✓ Setup
# Base directory:
# Device: cuda
#
# Loading data...
# ✓ train: 167454 | dev: 1200 | corpus: 526329
# ✓ Corpus built: 526329 documents
#
# Loading Contriever from local: models/contriever
# ✓ Encoders ready
# Doc max seq len: 512 | Query max seq len: 512
#
# Loading precomputed corpus embeddings: indices/corpus/embeddings.pt
# ✓ corpus_embeddings: (526329, 768)
#
# ...
# TRAINING (ADORE-style)
# ...
# Epoch 1/3: 100%|█| 2617/2617 [06:51<00:00,  6.36it/s, loss=0.2913, pairs=30, ste
# Epoch 1 avg loss: 0.2587
# ✓ Saved ADORE query encoder: output/adore/adore_model
# Epoch 2/3: 100%|█| 2617/2617 [06:46<00:00,  6.44it/s, loss=0.3282, pairs=30, ste
# Epoch 2 avg loss: 0.2575
# ✓ Saved ADORE query encoder: output/adore/adore_model
# Epoch 3/3: 100%|█| 2617/2617 [06:46<00:00,  6.44it/s, loss=0.2338, pairs=30, ste
# Epoch 3 avg loss: 0.2560
# ✓ Saved ADORE query encoder: output/adore/adore_model
#
# ✓ ADORE training complete
# Figure(1600x500)
# ...

# %%
# !python adore_script2.py
# Out:
# Importing libraries...
# Setting up paths and config...
# ✓ Setup complete
#   Device: cuda
#
# Loading data...
# ✓ Loaded: train=167454 | dev=1200 | corpus=526329
# ✓ Corpus: 526329 documents
#
# ...
# Loading READER MODEL (Flan-T5)
# ...
# ✓ Reader model loaded and FROZEN
#
# Loading Contriever encoders...
# ✓ Doc encoder: FROZEN
# ✓ Query encoder: TRAINABLE
#
# Loading cached corpus embeddings...
# ✓ Corpus embeddings: (526329, 768)
#
# ...
# ADORE TRAINING (HYBRID)
# ...
# Strategy:
#   - Positives: from GOLD supporting_facts (reliable)
#   - Negatives: READER-guided hard negative selection
#   - ΔM: based on retrieval rank difference
# ...
#
# Epoch 1/1:  17%|▉     | 432/2617 [09:33<48:34,  1.33s/it, loss=0.0600, pairs=64]
